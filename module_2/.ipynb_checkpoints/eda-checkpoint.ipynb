# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

# %%
df = pd.read_csv("stud_math.csv")

# %%
columns04 = ['Medu', 'Fedu']
columns14 = ['traveltime', 'studytime']
columns15 = ['famrel', 'freetime', 'goout', 'health']

def view_string_column(df, column):
  if df[column].dtype == 'object':
    display(df[column].value_counts())
    print('{} - NaN\n'.format(len(df[column][df[column].isna()])))
  return None

def view_numeric_column(df, column):
  if df[column].dtype == 'float64':
    display(df[column].value_counts())
    print('{} - NaN\n'.format(len(df[column][df[column].isna()])))
  return None

def draw_hist(df, column):
  fig = plt.figure()
  axes = fig.add_axes([0, 0, 1, 1])
  axes.hist(df[column])
  axes.set_title(column)
  return None

def draw_numeric_column(df, column):
  if df[column].dtype == 'float64':
    draw_hist(df, column)
  return None

def string_to_bool(df, column):
  if df[column].dtype == 'object':
    if {'yes', 'no'} == set(df[column].str.cat(sep=',').split(',')):
      return df[column].astype(str).apply(lambda x: True if x == 'yes' else False if x == 'no' else None)
  return df[column]  

def out_values(df, column, inter='linear'):
  iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
  perc25 = df[column].quantile(q=0.25, interpolation=inter)
  perc75 = df[column].quantile(0.75, interpolation=inter)
  return df[column].apply(lambda x: None if x<(perc25 - 1.5*iqr) or x>(perc75 + 1.5*iqr) else x)

def out_values_range(df, column, val_range):
  x,y = val_range
  return df[column].apply(lambda c: c if ((c%1)==0) and (c in range(x, y)) else None)

'''def out_values14(df, column):
  return df[column].apply(lambda x: x if x in range(1,5) else None)

def out_values15(df, column):
  return df[column].apply(lambda x: x if x in range(1,6) else None)'''

def fillna_median(df, column):
  return df[column].fillna(df[column].median())

def get_boxplot(df, column):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(x=column, y='score', 
                data=df.loc[df.loc[:, column].isin(df.loc[:, column].value_counts().index[:10])],
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()
    
def get_stat_dif(df, column):
    cols = df.loc[:, column].value_counts().index[:]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(df.loc[df.loc[:, column] == comb[0], 'score'], 
                        df.loc[df.loc[:, column] == comb[1], 'score']).pvalue \
            <= 0.05/len(combinations_all): # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break
    else:
        print('Cтатистически значимые различия для колонки', column, 'не найдены!')

# %%
for column in df.columns:
  df[column] = string_to_bool(df, column)

# %%
df.corr()
# Out:
#                           age      Medu      Fedu  traveltime  studytime  \
# age                  1.000000  0.091179  0.143312    0.338536   0.092465
# Medu                 0.091179  1.000000  0.751702   -0.161697   0.040386
# Fedu                 0.143312  0.751702  1.000000   -0.014560  -0.388724
# traveltime           0.338536 -0.161697 -0.014560    1.000000  -0.083851
# studytime            0.092465  0.040386 -0.388724   -0.083851   1.000000
# failures            -0.077342 -0.263221 -0.097235    0.058378  -0.094671
# studytime, granular -0.092465 -0.040386  0.388724    0.083851  -1.000000
# famrel              -0.044394  0.093374 -0.275622    0.101670   0.068285
# freetime             0.078592  0.316012  0.346871    0.134682  -0.122601
# goout                0.585799  0.119551  0.125503    0.133703  -0.121954
# health              -0.342339 -0.009325 -0.141235   -0.573190   0.114725
# absences             0.116939  0.123252  0.040588   -0.341473  -0.386088
# score               -0.200254 -0.211852 -0.384566    0.383814   0.326336
#
#                      failures  studytime, granular    famrel  freetime  \
# age                 -0.077342            -0.092465 -0.044394  0.078592
# Medu                -0.263221            -0.040386  0.093374  0.316012
# Fedu                -0.097235             0.388724 -0.275622  0.346871
# traveltime           0.058378             0.083851  0.101670  0.134682
# studytime           -0.094671            -1.000000  0.068285 -0.122601
# failures             1.000000             0.094671 -0.229487 -0.156464
# studytime, granular  0.094671             1.000000 -0.068285  0.122601
# famrel              -0.229487            -0.068285  1.000000 -0.144129
# freetime            -0.156464             0.122601 -0.144129  1.000000
# goout               -0.054611             0.121954 -0.067283  0.213584
# health              -0.031622            -0.114725 -0.035369 -0.162396
# absences             0.247866             0.386088  0.116381 -0.286819
# score               -0.114829            -0.326336 -0.009580  0.241270
#
#                         goout    health  absences     score
# age                  0.585799 -0.342339  0.116939 -0.200254
# Medu                 0.119551 -0.009325  0.123252 -0.211852
# Fedu                 0.125503 -0.141235  0.040588 -0.384566
# traveltime           0.133703 -0.573190 -0.341473  0.383814
# studytime           -0.121954  0.114725 -0.386088  0.326336
# failures            -0.054611 -0.031622  0.247866 -0.114829
# studytime, granular  0.121954 -0.114725  0.386088 -0.326336
# famrel              -0.067283 -0.035369  0.116381 -0.009580
# freetime             0.213584 -0.162396 -0.286819  0.241270
# goout                1.000000 -0.197666  0.463948 -0.167063
# health              -0.197666  1.000000  0.233240 -0.292478
# absences             0.463948  0.233240  1.000000 -0.589342
# score               -0.167063 -0.292478 -0.589342  1.000000

# %%
for column in columns04:
  df[column] = out_values_range(df, column, (0,5))
for column in columns14:
  df[column] = out_values_range(df, column, (1,5))
for column in columns15:
  df[column] = out_values_range(df, column, (1,6))
df['failures'] = out_values_range(df, 'failures', (0,4))

# %%
df['score'] = out_values(df, 'score')

# %%
 df['absences'] = out_values(df, 'absences', inter='midpoint')

# %%
for item in df.columns:
  view_numeric_column(df, item)
# Out:
# 4.0    131
# 2.0    102
# 3.0     97
# 1.0     59
# 0.0      3
# Name: Medu, dtype: int64
# 3 - NaN
# 2.0    106
# 3.0     96
# 4.0     88
# 1.0     78
# 0.0      2
# Name: Fedu, dtype: int64
# 25 - NaN
# 1.0    242
# 2.0     96
# 3.0     22
# 4.0      7
# Name: traveltime, dtype: int64
# 28 - NaN
# 2.0    194
# 1.0    103
# 3.0     64
# 4.0     27
# Name: studytime, dtype: int64
# 7 - NaN
# 0.0    293
# 1.0     49
# 2.0     16
# 3.0     15
# Name: failures, dtype: int64
# 22 - NaN
# -6.0     194
# -3.0     103
# -9.0      64
# -12.0     27
# Name: studytime, granular, dtype: int64
# 7 - NaN
# 4.0    182
# 5.0     99
# 3.0     62
# 2.0     17
# 1.0      7
# Name: famrel, dtype: int64
# 28 - NaN
# 3.0    153
# 4.0    112
# 2.0     63
# 5.0     38
# 1.0     18
# Name: freetime, dtype: int64
# 11 - NaN
# 3.0    127
# 2.0    101
# 4.0     84
# 5.0     52
# 1.0     23
# Name: goout, dtype: int64
# 8 - NaN
# 5.0    138
# 3.0     89
# 4.0     63
# 1.0     47
# 2.0     43
# Name: health, dtype: int64
# 15 - NaN
# 0.0     111
# 2.0      60
# 4.0      53
# 6.0      31
# 8.0      21
# 10.0     17
# 12.0     12
# 14.0     12
# 3.0       8
# 16.0      7
# 7.0       6
# 18.0      5
# 5.0       5
# 20.0      4
# 1.0       3
# 9.0       3
# 11.0      2
# 13.0      2
# 15.0      2
# 19.0      1
# 17.0      1
# Name: absences, dtype: int64
# 29 - NaN
# 50.0     54
# 55.0     46
# 0.0      37
# 75.0     33
# 65.0     31
# 40.0     31
# 60.0     31
# 70.0     27
# 45.0     27
# 80.0     16
# 30.0     15
# 90.0     12
# 35.0      9
# 25.0      7
# 85.0      6
# 95.0      5
# 100.0     1
# 20.0      1
# Name: score, dtype: int64
# 6 - NaN

# %%
df = df.loc[df.score.dropna()]

# %%
for column in columns04:
  df[column] = fillna_median(df, column)
for column in columns14:
  df[column] = fillna_median(df, column)
for column in columns15:
  df[column] = fillna_median(df, column)

# %%
df['absences'] = df['absences'].fillna(round(df['absences'].mean()))

# %%
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 30.0     GP   M   15       U     GT3       T   4.0   4.0    health  services
# 30.0     GP   M   15       U     GT3       T   4.0   4.0    health  services
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# 75.0     GP   M   15     NaN     GT3       T   4.0   3.0   teacher     other
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 45.0     GP   F   15       U     LE3       A   4.0   3.0     other     other
# 80.0     GP   M   15       U     GT3       T   2.0   3.0     other  services
# 35.0     GP   F   15       U     GT3       T   2.0   3.0     other     other
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# 45.0     GP   F   15       U     LE3       A   4.0   3.0     other     other
#
#       ... studytime, granular higher  internet  romantic  famrel freetime  \
# 30.0  ...                -6.0    yes       yes        no     5.0      4.0
# 30.0  ...                -6.0    yes       yes        no     5.0      4.0
# 50.0  ...                -6.0    yes       yes        no     4.0      3.0
# 75.0  ...                -6.0    yes       yes       NaN     4.0      3.0
# 50.0  ...                -6.0    yes       yes        no     4.0      3.0
# ...   ...                 ...    ...       ...       ...     ...      ...
# 45.0  ...                -6.0    yes       yes       yes     5.0      2.0
# 80.0  ...                -3.0    yes       NaN       yes     3.0      2.0
# 35.0  ...                -3.0    yes        no        no     3.0      5.0
# 50.0  ...                -6.0    yes       yes        no     4.0      3.0
# 45.0  ...                -6.0    yes       yes       yes     5.0      2.0
#
#      goout health absences score
# 30.0   2.0    4.0      0.0  60.0
# 30.0   2.0    4.0      0.0  60.0
# 50.0   3.0    4.0      2.0  65.0
# 75.0   3.0    5.0      6.0  50.0
# 50.0   3.0    4.0      2.0  65.0
# ...    ...    ...      ...   ...
# 45.0   2.0    5.0      8.0  30.0
# 80.0   2.0    3.0      2.0  60.0
# 35.0   1.0    5.0      0.0  30.0
# 50.0   3.0    4.0      2.0  65.0
# 45.0   2.0    5.0      8.0  30.0
#
# [389 rows x 30 columns]

# %%
sns.pairplot(df, kind = 'reg')

# %%
df.corr()
# Out:
#                           age      Medu      Fedu  traveltime  studytime  \
# age                  1.000000  0.091179  0.143312    0.338536   0.092465
# Medu                 0.091179  1.000000  0.751702   -0.161697   0.040386
# Fedu                 0.143312  0.751702  1.000000   -0.014560  -0.388724
# traveltime           0.338536 -0.161697 -0.014560    1.000000  -0.083851
# studytime            0.092465  0.040386 -0.388724   -0.083851   1.000000
# failures            -0.077342 -0.263221 -0.097235    0.058378  -0.094671
# studytime, granular -0.092465 -0.040386  0.388724    0.083851  -1.000000
# famrel              -0.044394  0.093374 -0.275622    0.101670   0.068285
# freetime             0.078592  0.316012  0.346871    0.134682  -0.122601
# goout                0.585799  0.119551  0.125503    0.133703  -0.121954
# health              -0.342339 -0.009325 -0.141235   -0.573190   0.114725
# absences             0.116939  0.123252  0.040588   -0.341473  -0.386088
# score               -0.200254 -0.211852 -0.384566    0.383814   0.326336
#
#                      failures  studytime, granular    famrel  freetime  \
# age                 -0.077342            -0.092465 -0.044394  0.078592
# Medu                -0.263221            -0.040386  0.093374  0.316012
# Fedu                -0.097235             0.388724 -0.275622  0.346871
# traveltime           0.058378             0.083851  0.101670  0.134682
# studytime           -0.094671            -1.000000  0.068285 -0.122601
# failures             1.000000             0.094671 -0.229487 -0.156464
# studytime, granular  0.094671             1.000000 -0.068285  0.122601
# famrel              -0.229487            -0.068285  1.000000 -0.144129
# freetime            -0.156464             0.122601 -0.144129  1.000000
# goout               -0.054611             0.121954 -0.067283  0.213584
# health              -0.031622            -0.114725 -0.035369 -0.162396
# absences             0.247866             0.386088  0.116381 -0.286819
# score               -0.114829            -0.326336 -0.009580  0.241270
#
#                         goout    health  absences     score
# age                  0.585799 -0.342339  0.116939 -0.200254
# Medu                 0.119551 -0.009325  0.123252 -0.211852
# Fedu                 0.125503 -0.141235  0.040588 -0.384566
# traveltime           0.133703 -0.573190 -0.341473  0.383814
# studytime           -0.121954  0.114725 -0.386088  0.326336
# failures            -0.054611 -0.031622  0.247866 -0.114829
# studytime, granular  0.121954 -0.114725  0.386088 -0.326336
# famrel              -0.067283 -0.035369  0.116381 -0.009580
# freetime             0.213584 -0.162396 -0.286819  0.241270
# goout                1.000000 -0.197666  0.463948 -0.167063
# health              -0.197666  1.000000  0.233240 -0.292478
# absences             0.463948  0.233240  1.000000 -0.589342
# score               -0.167063 -0.292478 -0.589342  1.000000

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        get_boxplot(df, column)

# %%
df = df.drop(columns=['studytime, granular'])

# %%
df
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 30.0     GP   M   15       U     GT3       T   4.0   4.0    health  services
# 30.0     GP   M   15       U     GT3       T   4.0   4.0    health  services
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# 75.0     GP   M   15     NaN     GT3       T   4.0   3.0   teacher     other
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 45.0     GP   F   15       U     LE3       A   4.0   3.0     other     other
# 80.0     GP   M   15       U     GT3       T   2.0   3.0     other  services
# 35.0     GP   F   15       U     GT3       T   2.0   3.0     other     other
# 50.0     GP   F   16       U     LE3       T   2.0   2.0  services  services
# 45.0     GP   F   15       U     LE3       A   4.0   3.0     other     other
#
#       ... nursery higher  internet  romantic  famrel freetime goout health  \
# 30.0  ...      no    yes       yes        no     5.0      4.0   2.0    4.0
# 30.0  ...      no    yes       yes        no     5.0      4.0   2.0    4.0
# 50.0  ...     yes    yes       yes        no     4.0      3.0   3.0    4.0
# 75.0  ...     yes    yes       yes       NaN     4.0      3.0   3.0    5.0
# 50.0  ...     yes    yes       yes        no     4.0      3.0   3.0    4.0
# ...   ...     ...    ...       ...       ...     ...      ...   ...    ...
# 45.0  ...     yes    yes       yes       yes     5.0      2.0   2.0    5.0
# 80.0  ...      no    yes       NaN       yes     3.0      2.0   2.0    3.0
# 35.0  ...     yes    yes        no        no     3.0      5.0   1.0    5.0
# 50.0  ...     yes    yes       yes        no     4.0      3.0   3.0    4.0
# 45.0  ...     yes    yes       yes       yes     5.0      2.0   2.0    5.0
#
#      absences score
# 30.0      0.0  60.0
# 30.0      0.0  60.0
# 50.0      2.0  65.0
# 75.0      6.0  50.0
# 50.0      2.0  65.0
# ...       ...   ...
# 45.0      8.0  30.0
# 80.0      2.0  60.0
# 35.0      0.0  30.0
# 50.0      2.0  65.0
# 45.0      8.0  30.0
#
# [389 rows x 29 columns]

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        get_stat_dif(df, column)
# Out:
# Cтатистически значимые различия для колонки school не найдены!
# Найдены статистически значимые различия для колонки sex
# Cтатистически значимые различия для колонки address не найдены!
# Найдены статистически значимые различия для колонки famsize
# Найдены статистически значимые различия для колонки Pstatus
# Найдены статистически значимые различия для колонки Mjob
# Найдены статистически значимые различия для колонки Fjob
# Найдены статистически значимые различия для колонки reason
# Найдены статистически значимые различия для колонки guardian
# Найдены статистически значимые различия для колонки schoolsup
# Найдены статистически значимые различия для колонки famsup
# Cтатистически значимые различия для колонки paid не найдены!
# Cтатистически значимые различия для колонки activities не найдены!
# Cтатистически значимые различия для колонки nursery не найдены!
# Cтатистически значимые различия для колонки higher не найдены!
# Найдены статистически значимые различия для колонки internet
# Найдены статистически значимые различия для колонки romantic

# %%
df = df.drop(columns=['school', 'address', 'paid', 'activities', 'nursery', 'higher'])

# %%
df.head(10)
# Out:
#      sex  age famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason  \
# 30.0   M   15     GT3       T   4.0   4.0    health  services    home
# 30.0   M   15     GT3       T   4.0   4.0    health  services    home
# 50.0   F   16     LE3       T   2.0   2.0  services  services  course
# 75.0   M   15     GT3       T   4.0   3.0   teacher     other    home
# 50.0   F   16     LE3       T   2.0   2.0  services  services  course
# 75.0   M   15     GT3       T   4.0   3.0   teacher     other    home
# 55.0   F   16     GT3       A   2.0   1.0     other     other   other
# 30.0   M   15     GT3       T   4.0   4.0    health  services    home
# 95.0   F   15     GT3       T   1.0   1.0   at_home     other    home
# 75.0   M   15     GT3       T   4.0   3.0   teacher     other    home
#
#      guardian  ...  schoolsup  famsup  internet romantic famrel freetime  \
# 30.0   mother  ...         no     yes       yes       no    5.0      4.0
# 30.0   mother  ...         no     yes       yes       no    5.0      4.0
# 50.0   mother  ...         no     yes       yes       no    4.0      3.0
# 75.0   mother  ...         no     yes       yes      NaN    4.0      3.0
# 50.0   mother  ...         no     yes       yes       no    4.0      3.0
# 75.0   mother  ...         no     yes       yes      NaN    4.0      3.0
# 55.0   mother  ...         no      no       yes      yes    5.0      3.0
# 30.0   mother  ...         no     yes       yes       no    5.0      4.0
# 95.0   mother  ...        yes     yes       yes       no    3.0      1.0
# 75.0   mother  ...         no     yes       yes      NaN    4.0      3.0
#
#      goout  health  absences  score
# 30.0   2.0     4.0       0.0   60.0
# 30.0   2.0     4.0       0.0   60.0
# 50.0   3.0     4.0       2.0   65.0
# 75.0   3.0     5.0       6.0   50.0
# 50.0   3.0     4.0       2.0   65.0
# 75.0   3.0     5.0       6.0   50.0
# 55.0   4.0     4.0       8.0   50.0
# 30.0   2.0     4.0       0.0   60.0
# 95.0   2.0     1.0       2.0   50.0
# 75.0   3.0     5.0       6.0   50.0
#
# [10 rows x 23 columns]
